# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.4.4-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.4-cp311-cp311-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install seaborn scikit-learn matplotlib pandas
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting pandas
#   Using cached pandas-3.0.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\aesha\miniconda3\envs\nasa\Lib\site-packages (from seaborn) (2.4.4)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.62.1-cp311-cp311-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\aesha\miniconda3\envs\nasa\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.2.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\aesha\miniconda3\envs\nasa\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\aesha\miniconda3\envs\nasa\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\aesha\miniconda3\envs\nasa\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 524.3 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/8.1 MB 986.7 kB/s eta 0:00:08
#    ------- -------------------------------- 1.6/8.1 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.1 MB 1.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.1 MB 1.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.1 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.1 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.9 MB/s  0:00:04
# Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached pandas-3.0.2-cp311-cp311-win_amd64.whl (9.9 MB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Using cached pillow-12.2.0-cp311-cp311-win_amd64.whl (7.1 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.6 MB 3.0 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/36.6 MB 3.2 MB/s eta 0:00:12
#    -- ------------------------------------- 2.1/36.6 MB 2.8 MB/s eta 0:00:13
#    -- ------------------------------------- 2.6/36.6 MB 2.8 MB/s eta 0:00:13
#    --- ------------------------------------ 3.4/36.6 MB 2.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 3.7/36.6 MB 2.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 3.7/36.6 MB 2.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.2/36.6 MB 2.3 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.2/36.6 MB 2.3 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.0/36.6 MB 2.3 MB/s eta 0:00:14
#    ------ --------------------------------- 5.8/36.6 MB 2.5 MB/s eta 0:00:13
#    ------- -------------------------------- 6.6/36.6 MB 2.5 MB/s eta 0:00:13
#    ------- -------------------------------- 6.8/36.6 MB 2.4 MB/s eta 0:00:13
#    ------- -------------------------------- 6.8/36.6 MB 2.4 MB/s eta 0:00:13
#    -------- ------------------------------- 7.6/36.6 MB 2.4 MB/s eta 0:00:13
#    -------- ------------------------------- 8.1/36.6 MB 2.4 MB/s eta 0:00:12
#    --------- ------------------------------ 8.4/36.6 MB 2.3 MB/s eta 0:00:13
#    --------- ------------------------------ 8.7/36.6 MB 2.2 MB/s eta 0:00:13
#    --------- ------------------------------ 8.9/36.6 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 9.4/36.6 MB 2.2 MB/s eta 0:00:13
#    ---------- ----------------------------- 9.7/36.6 MB 2.2 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.0/36.6 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.2/36.6 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.7/36.6 MB 2.1 MB/s eta 0:00:13
#    ------------ --------------------------- 11.3/36.6 MB 2.1 MB/s eta 0:00:13
#    ------------ --------------------------- 11.5/36.6 MB 2.1 MB/s eta 0:00:12
#    ------------ --------------------------- 11.8/36.6 MB 2.1 MB/s eta 0:00:12
#    ------------- -------------------------- 12.3/36.6 MB 2.1 MB/s eta 0:00:12
#    ------------- -------------------------- 12.6/36.6 MB 2.1 MB/s eta 0:00:12
#    -------------- ------------------------- 13.1/36.6 MB 2.1 MB/s eta 0:00:12
#    -------------- ------------------------- 13.6/36.6 MB 2.1 MB/s eta 0:00:12
#    --------------- ------------------------ 14.2/36.6 MB 2.1 MB/s eta 0:00:11
#    ---------------- ----------------------- 14.7/36.6 MB 2.1 MB/s eta 0:00:11
#    ---------------- ----------------------- 14.9/36.6 MB 2.1 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.5/36.6 MB 2.1 MB/s eta 0:00:11
#    ----------------- ---------------------- 16.0/36.6 MB 2.1 MB/s eta 0:00:10
#    ----------------- ---------------------- 16.3/36.6 MB 2.1 MB/s eta 0:00:10
#    ------------------ --------------------- 16.8/36.6 MB 2.1 MB/s eta 0:00:10
#    ------------------ --------------------- 17.0/36.6 MB 2.1 MB/s eta 0:00:10
#    ------------------- -------------------- 17.6/36.6 MB 2.1 MB/s eta 0:00:10
#    ------------------- -------------------- 18.1/36.6 MB 2.1 MB/s eta 0:00:09
#    -------------------- ------------------- 18.6/36.6 MB 2.1 MB/s eta 0:00:09
#    -------------------- ------------------- 19.1/36.6 MB 2.1 MB/s eta 0:00:09
#    --------------------- ------------------ 19.4/36.6 MB 2.1 MB/s eta 0:00:09
#    --------------------- ------------------ 19.7/36.6 MB 2.1 MB/s eta 0:00:09
#    ---------------------- ----------------- 20.2/36.6 MB 2.1 MB/s eta 0:00:08
#    ---------------------- ----------------- 20.4/36.6 MB 2.1 MB/s eta 0:00:08
#    ---------------------- ----------------- 20.7/36.6 MB 2.1 MB/s eta 0:00:08
#    ----------------------- ---------------- 21.2/36.6 MB 2.1 MB/s eta 0:00:08
#    ----------------------- ---------------- 21.5/36.6 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 22.0/36.6 MB 2.1 MB/s eta 0:00:08
#    ------------------------ --------------- 22.5/36.6 MB 2.0 MB/s eta 0:00:07
#    ------------------------ --------------- 22.8/36.6 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.1/36.6 MB 2.1 MB/s eta 0:00:07
#    ------------------------- -------------- 23.3/36.6 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.6/36.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 24.1/36.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 24.6/36.6 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 25.2/36.6 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 25.4/36.6 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.0/36.6 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.5/36.6 MB 2.0 MB/s eta 0:00:05
#    ----------------------------- ---------- 27.0/36.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 27.5/36.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 28.0/36.6 MB 2.1 MB/s eta 0:00:05
#    ------------------------------ --------- 28.0/36.6 MB 2.1 MB/s eta 0:00:05
#    ------------------------------ --------- 28.3/36.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------- -------- 28.8/36.6 MB 2.0 MB/s eta 0:00:04
#    ------------------------------- -------- 29.1/36.6 MB 2.0 MB/s eta 0:00:04
#    -------------------------------- ------- 29.6/36.6 MB 2.0 MB/s eta 0:00:04
#    -------------------------------- ------- 29.9/36.6 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 30.4/36.6 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 30.9/36.6 MB 2.0 MB/s eta 0:00:03
#    --------------------------------- ------ 30.9/36.6 MB 2.0 MB/s eta 0:00:03
#    --------------------------------- ------ 30.9/36.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.5/36.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.7/36.6 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.2/36.6 MB 2.0 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.5/36.6 MB 2.0 MB/s eta 0:00:03
#    ------------------------------------ --- 33.0/36.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.3/36.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.6/36.6 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.8/36.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 34.1/36.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 34.6/36.6 MB 1.9 MB/s eta 0:00:02
#    -------------------------------------- - 34.9/36.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 35.1/36.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 1.9 MB/s  0:00:19
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, pandas, matplotlib, seaborn
#
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------------- ------------------------  5/13 [joblib]
#    --------------- ------------------------  5/13 [joblib]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------------ ---------------  8/13 [contourpy]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.8 pandas-3.0.2 pillow-12.2.0 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
files = [
    'archive/CMaps/train_FD001.txt',
    'archive/CMaps/train_FD002.txt',
    'archive/CMaps/train_FD003.txt',
    'archive/CMaps/train_FD004.txt'
]

for idx, file in enumerate(files, start=1):
    raw_data = pd.read_csv(file, sep=' ', header=None)

    # Drop extra columns
    raw_data = raw_data.drop([26, 27], axis=1)

    # Rename columns
    raw_data.columns = [
        'ID','Cycle','OpSet1','OpSet2','OpSet3',
        'SensorMeasure1','SensorMeasure2','SensorMeasure3','SensorMeasure4','SensorMeasure5',
        'SensorMeasure6','SensorMeasure7','SensorMeasure8','SensorMeasure9','SensorMeasure10',
        'SensorMeasure11','SensorMeasure12','SensorMeasure13','SensorMeasure14','SensorMeasure15',
        'SensorMeasure16','SensorMeasure17','SensorMeasure18','SensorMeasure19','SensorMeasure20','SensorMeasure21'
    ]

    # ✅ Efficient EOL calculation
    eol_map = raw_data.groupby('ID')['Cycle'].max()
    raw_data['EOL'] = raw_data['ID'].map(eol_map)

    # Life Ratio
    raw_data['LR'] = raw_data['Cycle'] / raw_data['EOL']

    # Drop unnecessary columns
    raw_data = raw_data.drop(columns=['ID', 'EOL'])

    # Vectorized labeling 
    conditions = [
        raw_data['LR'] <= 0.6,
        (raw_data['LR'] > 0.6) & (raw_data['LR'] <= 0.8),
        raw_data['LR'] > 0.8
    ]
    choices = [0, 1, 2]

    raw_data['labels'] = np.select(conditions, choices)

    raw_data = raw_data.drop(columns=['LR'])

    # Save file
    raw_data.to_csv(f'Training_{idx}_all_features.csv', index=False)

# %%
df1 = pd.read_csv('Training_1_all_features.csv')
df2 = pd.read_csv('Training_2_all_features.csv')
df3 = pd.read_csv('Training_3_all_features.csv')
df4 = pd.read_csv('Training_4_all_features.csv')

# %%
df = pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#        Cycle   OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 0          1  -0.0007 -0.0004   100.0          518.67          641.82
# 1          2   0.0019 -0.0003   100.0          518.67          642.15
# 2          3  -0.0043  0.0003   100.0          518.67          642.35
# 3          4   0.0007  0.0000   100.0          518.67          642.35
# 4          5  -0.0019 -0.0002   100.0          518.67          642.37
# ...      ...      ...     ...     ...             ...             ...
# 61244    251   9.9998  0.2500   100.0          489.05          605.33
# 61245    252   0.0028  0.0015   100.0          518.67          643.42
# 61246    253   0.0029  0.0000   100.0          518.67          643.68
# 61247    254  35.0046  0.8400   100.0          449.44          555.77
# 61248    255  42.0030  0.8400   100.0          445.00          549.85
#
#        SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# 0             1589.70         1400.60           14.62           21.61  ...
# 1             1591.82         1403.14           14.62           21.61  ...
# 2             1587.99         1404.20           14.62           21.61  ...
# 3             1582.79         1401.87           14.62           21.61  ...
# 4             1582.85         1406.22           14.62           21.61  ...
# ...               ...             ...             ...             ...  ...
# 61244         1516.36         1315.28           10.52           15.46  ...
# 61245         1598.92         1426.77           14.62           21.57  ...
# 61246         1607.72         1430.56           14.62           21.57  ...
# 61247         1381.29         1148.18            5.48            7.96  ...
# 61248         1369.75         1147.45            3.91            5.69  ...
#
#        SensorMeasure13  SensorMeasure14  SensorMeasure15  SensorMeasure16  \
# 0              2388.02          8138.62           8.4195             0.03
# 1              2388.07          8131.49           8.4318             0.03
# 2              2388.03          8133.23           8.4178             0.03
# 3              2388.08          8133.83           8.3682             0.03
# 4              2388.04          8133.80           8.4294             0.03
# ...                ...              ...              ...              ...
# 61244          2388.73          8185.69           8.4541             0.03
# 61245          2388.46          8185.47           8.2221             0.03
# 61246          2388.48          8193.94           8.2525             0.03
# 61247          2388.83          8125.64           9.0515             0.02
# 61248          2388.66          8144.33           9.1207             0.02
#
#        SensorMeasure17  SensorMeasure18  SensorMeasure19  SensorMeasure20  \
# 0                  392             2388            100.0            39.06
# 1                  392             2388            100.0            39.00
# 2                  390             2388            100.0            38.95
# 3                  392             2388            100.0            38.88
# 4                  393             2388            100.0            38.90
# ...                ...              ...              ...              ...
# 61244              372             2319            100.0            29.11
# 61245              396             2388            100.0            39.38
# 61246              395             2388            100.0            39.78
# 61247              337             2223            100.0            15.26
# 61248              333             2212            100.0            10.66
#
#        SensorMeasure21  labels
# 0              23.4190       0
# 1              23.4236       0
# 2              23.3442       0
# 3              23.3739       0
# 4              23.4044       0
# ...                ...     ...
# 61244          17.5234       2
# 61245          23.7151       2
# 61246          23.8270       2
# 61247           9.0774       2
# 61248           6.4341       2
#
# [160359 rows x 26 columns]

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_RF = RF.predict(X_test)

cm = pd.DataFrame(confusion_matrix(y_test, y_pred_RF, normalize ='true')*100)
colormap = sns.color_palette("Reds")
sns.heatmap(cm, annot=True,cmap=colormap)

accuracy_score(y_test, y_pred_RF)
# Out:
# 0.8926166126216014

# %%
RF.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_pred_RF = RF.predict(X_train)

cm = pd.DataFrame(confusion_matrix(y_train, y_pred_RF, normalize ='true')*100)
colormap = sns.color_palette("Blues")
sns.heatmap(cm, annot=True,cmap=colormap)

accuracy_score(y_train, y_pred_RF)
# Out:
# 1.0

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators=[200, 400, 300]
# Maximum number of levels in tree
max_depth= [10, 20, 30]
# Max number of samples given to each tree 
max_samples= [0.2,0.3,0.4 ]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'max_samples': max_samples}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 300], 'max_depth': [10, 20, 30], 'max_samples': [0.2, 0.3, 0.4]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestClassifier()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, cv = 3,n_jobs=-1)
# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30],
#                                         'max_samples': [0.2, 0.3, 0.4],
#                                         'n_estimators': [200, 400, 300]})

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 300, 'max_samples': 0.4, 'max_depth': 20}

# %%
rf_random.best_score_
# Out:
# np.float64(0.8899551640848243)

# %%
RF_randSer = RandomForestClassifier(n_estimators=300,max_samples=0.4,max_depth= 20)
RF_randSer.fit(X_train, y_train)
y_pred_RF = RF_randSer.predict(X_test)

cm = pd.DataFrame(confusion_matrix(y_test, y_pred_RF, normalize ='true')*100)
colormap = sns.color_palette("Reds")
sns.heatmap(cm, annot=True,cmap=colormap)

accuracy_score(y_test, y_pred_RF)
# Out:
# 0.893926166126216

# %%
df1 = pd.read_csv('Test_classification_1.csv')
df2 = pd.read_csv('Test_classification_2.csv')
df3 = pd.read_csv('Test_classification_3.csv')
df4 = pd.read_csv('Test_classification_4.csv')

test_df = pd.concat([df1,df2,df3,df4])

X_test = test_df.iloc[:,0:-1]
y_test = test_df.iloc[:,-1]

# %%
y_pred_RF = RF_randSer.predict(X_test)

cm = pd.DataFrame(confusion_matrix(y_test, y_pred_RF, normalize ='true')*100)
colormap = sns.color_palette("Reds")
sns.heatmap(cm, annot=True,cmap=colormap)

accuracy_score(y_test, y_pred_RF)
# Out:
# 0.907127944555135
